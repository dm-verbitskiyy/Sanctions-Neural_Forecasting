# %% [markdown]
# # Задание
# Бизнесу хочется понять, сколько пользователей в фитмосте и как долго они остаются с нами. Это значит, что они хотят увидеть ретеншн пользователей по их покупкам.
#
# У вас есть два датасета:
#
# #### users_payments:
# account_id INT — айдишник пользователя, purchase_date datetime — дата покупки, amount INT — сумма покупки.
#
# #### accounts:
# account_id INT — айдишник пользователя, status String — статус пользователя, project_name String — код проекта
#
#
# ---
# #### Содержание:
#
# 1) Подготовка данных
#
# 2) PY
#
# 3) SQL
#
# 4) Вывод по Ретеншну
#
# 5) Мнение по значимости и расчету метрики ретеншн для бизнеса

# %% [markdown]
# ---
# ### 1) Подготовка данных

# %%
import pandas as pd
import pyarrow.parquet as pq
import sqlite3

# %%
accounts = pq.read_table('~/accounts.parquet')
users_payments = pq.read_table('~/users_payments.parquet')

users_payments = users_payments.to_pandas()
accounts = accounts.to_pandas()

# %%
users_payments.head()
# Out:
#    account_id       purchase_date  amount
# 0    474724.0 2022-12-31 04:39:55   584.0
# 1    789265.0 2021-10-31 22:48:01   807.0
# 2    418333.0 2021-03-31 17:26:43   629.0
# 3    265787.0 2021-06-30 11:21:04   555.0
# 4    755766.0 2022-12-31 17:19:33   628.0

# %%
accounts.head()
# Out:
#    account_id  status project_name
# 0      474724  active         fm
# 1      789265  active         fm
# 2      418333  active         fm
# 3      265787  active         fm
# 4      755766  active         fm

# %%
print(users_payments.info())
print(accounts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5601516 entries, 0 to 5601515
# Data columns (total 3 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   account_id     float64
#  1   purchase_date  datetime64[ns]
#  2   amount         float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 128.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429400 entries, 0 to 429399
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   account_id    429400 non-null  int64
#  1   status        409400 non-null  object
#  2   project_name  429400 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 9.8+ MB
# None

# %% [markdown]
# Типы данных отличаются от ТЗ, меняю на необходимые.

# %%
float_columns = ['account_id', 'amount']
users_payments = users_payments.dropna(subset=float_columns)
users_payments[float_columns] = users_payments[float_columns].astype(int)

# Меняю дату на '%Y-%m-%d' для удобства расчета. 
users_payments['purchase_date'] = pd.to_datetime(users_payments['purchase_date'], format='%Y-%m-%d').dt.date


object_columns = ['status', 'project_name']
accounts[object_columns] = accounts[object_columns].astype(str)
# Обратил внимание на стринг-у, object не поменялся в str, 
# как я понял, это произошло из-за того, что в этих колонках данные уже записаны в формате str.

# %%
accounts.status.value_counts()
# Out:
# active     380911
# nan         20000
# double      16144
# blocked     12345
# Name: status, dtype: int64

# %% [markdown]
# У юзеров несколько статусов, принял решение брать в расчет только активных пользователей.

# %%
accounts.project_name.value_counts()
# Out:
# fm      400828
# fm       20000
# kd        8572
# Name: project_name, dtype: int64

# %% [markdown]
# Пользователи проекта fm записались с ошибкой, предполагаю, что есть пробел. Увидел количественное сходство со статусом nan, возможно есть взаимосвязь.

# %%
cross_table_accounts = pd.crosstab(accounts['status'], accounts['project_name'])
print(cross_table_accounts)
# Out:
# project_name      fm   fm      kd
# status
# active        355599  17729  7583
# blocked        11484    576   285
# double         15085    735   324
# nan            18660    960   380

# %% [markdown]
# Создал кросс-таблицу, все таки nan и fm не коррелируют.

# %%
grouped_accounts = accounts.groupby(['status', 'project_name']).size().reset_index(name='count')
print(grouped_accounts)
# Out:
#      status project_name   count
# 0    active           fm  355599
# 1    active         fm     17729
# 2    active           kd    7583
# 3   blocked           fm   11484
# 4   blocked         fm       576
# 5   blocked           kd     285
# 6    double           fm   15085
# 7    double         fm       735
# 8    double           kd     324
# 9       nan           fm   18660
# 10      nan         fm       960
# 11      nan           kd     380

# %% [markdown]
# На всякий случай вывел в ином варианте записи ту же таблицу, стало понятно, что нужно избавиться от пробелов.

# %%
accounts['project_name'] = accounts['project_name'].str.replace(' ', '')

# %%
fm_accounts = accounts[accounts['project_name'] == 'fm']

# %%
missing_values_users_payments = users_payments.isnull().sum()
missing_values_fm_accounts = fm_accounts.isnull().sum()

print("Пропущенные значения в 'users_payments':\n", missing_values_users_payments)
print("Пропущенные значения в 'accounts' для fm:\n", missing_values_fm_accounts)
# Out:
# Пропущенные значения в 'users_payments':
#  account_id       0
# purchase_date    0
# amount           0
# dtype: int64
# Пропущенные значения в 'accounts' для fm:
#  account_id      0
# status          0
# project_name    0
# dtype: int64

# %% [markdown]
# Пропуски отсутствуют, отлично.

# %%
merged_fm_acc_up = pd.merge(users_payments, fm_accounts, on='account_id')

# %%
merged_fm_acc_up.head()
# Out:
#    account_id purchase_date  amount  status project_name
# 0      474724    2022-12-31     584  active           fm
# 1      474724    2022-04-30     529  active           fm
# 2      474724    2021-03-31     722  active           fm
# 3      474724    2023-04-30     820  active           fm
# 4      474724    2021-05-31     775  active           fm

# %%
active_users = merged_fm_acc_up[merged_fm_acc_up['status'] == 'active']

# %%
active_users.head()
# Out:
#    account_id purchase_date  amount  status project_name
# 0      474724    2022-12-31     584  active           fm
# 1      474724    2022-04-30     529  active           fm
# 2      474724    2021-03-31     722  active           fm
# 3      474724    2023-04-30     820  active           fm
# 4      474724    2021-05-31     775  active           fm

# %% [markdown]
# Мержу дф-ы проекта fm и с активным статусом айдишников

# %%
excel_file_path = 'cleared_data.xlsx'
active_users.to_excel(excel_file_path, index=False)

print(f'Таблица сохранена в файл {excel_file_path}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-142e1551818c> in <module>
#       1 excel_file_path = 'cleared_data.xlsx'
# ----> 2 active_users.to_excel(excel_file_path, index=False)
#       3
#       4 print(f'Таблица сохранена в файл {excel_file_path}')
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2027             startcol=startcol,
#    2028             freeze_panes=freeze_panes,
# -> 2029             engine=engine,
#    2030         )
#    2031
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     721         if num_rows > self.max_rows or num_cols > self.max_cols:
#     722             raise ValueError(
# --> 723                 f"This sheet is too large! Your sheet size is: {num_rows}, {num_cols} "
#     724                 f"Max sheet size is: {self.max_rows}, {self.max_cols}"
#     725             )
#
# ValueError: This sheet is too large! Your sheet size is: 4852147, 5 Max sheet size is: 1048576, 16384

# %% [markdown]
# На всякий случай выгружаю чистые данные. Но в моем юпитере стоят ограничения на размер дф-ов.
#
#
# ---
# ### 2) PY

# %%
active_users['account_id'].nunique()
# Out:
# 373328

# %%
active_users['first_transaction_month'] = active_users['purchase_date'].astype('datetime64[M]')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Определяю дату первой транзакции только по месяцу и году.

# %%
active_users.groupby(['first_transaction_month'])['account_id'].agg(['count', 'nunique']).reset_index()
# Out:
#    first_transaction_month   count  nunique
# 0               2021-01-01  134123   113035
# 1               2021-02-01  135345   113892
# 2               2021-03-01  134846   113450
# 3               2021-04-01  134936   113404
# 4               2021-05-01  134706   113441
# 5               2021-06-01  135053   113586
# 6               2021-07-01  135222   113701
# 7               2021-08-01  134576   113288
# 8               2021-09-01  134748   113644
# 9               2021-10-01  134089   112825
# 10              2021-11-01  134254   112914
# 11              2021-12-01  134749   113478
# 12              2022-01-01  135454   113839
# 13              2022-02-01  134588   113285
# 14              2022-03-01  134672   113455
# 15              2022-04-01  134801   113305
# 16              2022-05-01  135033   113710
# 17              2022-06-01  135318   113871
# 18              2022-07-01  134982   113602
# 19              2022-08-01  135087   113713
# 20              2022-09-01  135730   114037
# 21              2022-10-01  134805   113385
# 22              2022-11-01  134365   113077
# 23              2022-12-01  134739   113589
# 24              2023-01-01  134811   113561
# 25              2023-02-01  134753   113279
# 26              2023-03-01  134989   113698
# 27              2023-04-01  135164   113590
# 28              2023-05-01  134192   113105
# 29              2023-06-01  134157   113039
# 30              2023-07-01  135292   113806
# 31              2023-08-01  134855   113435
# 32              2023-09-01  134502   113148
# 33              2023-10-01  134616   113318
# 34              2023-11-01  134074   112772
# 35              2023-12-01  134521   113213

# %%
id_ftm = active_users.groupby('account_id')['first_transaction_month'].min().reset_index()

# %%
id_ftm.head()
# Out:
#    account_id first_transaction_month
# 0           3              2021-01-01
# 1           7              2021-02-01
# 2           8              2021-04-01
# 3          10              2021-03-01
# 4          12              2021-07-01

# %% [markdown]
# Для каждого айдишника определяю первую дату активности

# %%
min_date = active_users.first_transaction_month.min()
max_date = active_users.first_transaction_month.max()

# %%
month = pd.DataFrame(pd.date_range(min_date, max_date, freq='MS'))
month.columns = ['month']
month.head()
# Out:
#        month
# 0 2021-01-01
# 1 2021-02-01
# 2 2021-03-01
# 3 2021-04-01
# 4 2021-05-01

# %% [markdown]
# Генерирую календарь от мин до макс даты первой активности.

# %%
id_ftm['key'] = 1
month['key'] = 1

# %%
monthly_data_dynamics = id_ftm.merge(month,on='key')[['account_id', 'first_transaction_month', 'month']]

# %%
monthly_data_dynamics = monthly_data_dynamics[monthly_data_dynamics['month'] >= monthly_data_dynamics['first_transaction_month']]

# %%
monthly_data_dynamics.head()
# Out:
#    account_id first_transaction_month      month
# 0           3              2021-01-01 2021-01-01
# 1           3              2021-01-01 2021-02-01
# 2           3              2021-01-01 2021-03-01
# 3           3              2021-01-01 2021-04-01
# 4           3              2021-01-01 2021-05-01

# %% [markdown]
# Мержу календарь и дф id_ftm, чтобы отобразить последовательнность.

# %%
trans_month = active_users.groupby(['account_id', 'first_transaction_month'])['amount'].sum().reset_index()

# %%
trans_month.columns = ['account_id', 'month', 'amount']
trans_month.head()
# Out:
#    account_id      month  amount
# 0           3 2021-01-01     535
# 1           3 2021-02-01     514
# 2           3 2021-06-01     726
# 3           3 2021-09-01     803
# 4           3 2021-12-01     567

# %% [markdown]
# Для каждого пользователя считаю месяц-год и покупку.

# %%
monthly_activity = monthly_data_dynamics.merge(trans_month, on=['account_id', 'month'], how='left')
# склеиваю при помощи how='left', чтобы как раз и отобразить пропуски
monthly_activity['active'] = (monthly_activity['amount'] > 0)*1
monthly_activity.head()
# Out:
#    account_id first_transaction_month      month  amount  active
# 0           3              2021-01-01 2021-01-01   535.0       1
# 1           3              2021-01-01 2021-02-01   514.0       1
# 2           3              2021-01-01 2021-03-01     NaN       0
# 3           3              2021-01-01 2021-04-01     NaN       0
# 4           3              2021-01-01 2021-05-01     NaN       0

# %% [markdown]
# Объединяю monthly_data_dynamics и trans_month, чтобы получить пропуски, когда айдишник не был активен.
#
# Так же добавляю столбец-определитель, по которому и буду считать ретеншн.

# %%
retention_py = monthly_activity.pivot_table(index='first_transaction_month', columns='month', values='active', aggfunc='mean')
retention_py

# вывожу расчитанный ретеншен при помощи пивотника с использованием функции mean
# Out:
# month                    2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# first_transaction_month
# 2021-01-01                      1.0    0.302225    0.300394    0.299819
# 2021-02-01                      NaN    1.000000    0.300138    0.300891
# 2021-03-01                      NaN         NaN    1.000000    0.304994
# 2021-04-01                      NaN         NaN         NaN    1.000000
# 2021-05-01                      NaN         NaN         NaN         NaN
# 2021-06-01                      NaN         NaN         NaN         NaN
# 2021-07-01                      NaN         NaN         NaN         NaN
# 2021-08-01                      NaN         NaN         NaN         NaN
# 2021-09-01                      NaN         NaN         NaN         NaN
# 2021-10-01                      NaN         NaN         NaN         NaN
# 2021-11-01                      NaN         NaN         NaN         NaN
# 2021-12-01                      NaN         NaN         NaN         NaN
# 2022-01-01                      NaN         NaN         NaN         NaN
# 2022-02-01                      NaN         NaN         NaN         NaN
# 2022-03-01                      NaN         NaN         NaN         NaN
# 2022-04-01                      NaN         NaN         NaN         NaN
# 2022-05-01                      NaN         NaN         NaN         NaN
# 2022-06-01                      NaN         NaN         NaN         NaN
# 2022-07-01                      NaN         NaN         NaN         NaN
# 2022-08-01                      NaN         NaN         NaN         NaN
# 2022-09-01                      NaN         NaN         NaN         NaN
# 2022-10-01                      NaN         NaN         NaN         NaN
# 2022-11-01                      NaN         NaN         NaN         NaN
# 2022-12-01                      NaN         NaN         NaN         NaN
# 2023-01-01                      NaN         NaN         NaN         NaN
# 2023-02-01                      NaN         NaN         NaN         NaN
# 2023-03-01                      NaN         NaN         NaN         NaN
#
# month                    2021-05-01  2021-06-01  2021-07-01  2021-08-01  \
# first_transaction_month
# 2021-01-01                 0.299341    0.301057    0.299695    0.300075
# 2021-02-01                 0.300426    0.302546    0.304327    0.301518
# 2021-03-01                 0.306308    0.301881    0.305768    0.301215
# 2021-04-01                 0.304663    0.306011    0.305363    0.302797
# 2021-05-01                 1.000000    0.307675    0.303657    0.306150
# 2021-06-01                      NaN    1.000000    0.301480    0.300242
# 2021-07-01                      NaN         NaN    1.000000    0.313680
# 2021-08-01                      NaN         NaN         NaN    1.000000
# 2021-09-01                      NaN         NaN         NaN         NaN
# 2021-10-01                      NaN         NaN         NaN         NaN
# 2021-11-01                      NaN         NaN         NaN         NaN
# 2021-12-01                      NaN         NaN         NaN         NaN
# 2022-01-01                      NaN         NaN         NaN         NaN
# 2022-02-01                      NaN         NaN         NaN         NaN
# 2022-03-01                      NaN         NaN         NaN         NaN
# 2022-04-01                      NaN         NaN         NaN         NaN
# 2022-05-01                      NaN         NaN         NaN         NaN
# 2022-06-01                      NaN         NaN         NaN         NaN
# 2022-07-01                      NaN         NaN         NaN         NaN
# 2022-08-01                      NaN         NaN         NaN         NaN
# 2022-09-01                      NaN         NaN         NaN         NaN
# 2022-10-01                      NaN         NaN         NaN         NaN
# 2022-11-01                      NaN         NaN         NaN         NaN
# 2022-12-01                      NaN         NaN         NaN         NaN
# 2023-01-01                      NaN         NaN         NaN         NaN
# 2023-02-01                      NaN         NaN         NaN         NaN
# 2023-03-01                      NaN         NaN         NaN         NaN
#
# month                    2021-09-01  2021-10-01  ...  2023-03-01  2023-04-01  \
# first_transaction_month                          ...
# 2021-01-01                 0.300615    0.297704  ...    0.302137    0.300022
# 2021-02-01                 0.300991    0.301681  ...    0.302421    0.300527
# 2021-03-01                 0.306830    0.301233  ...    0.302439    0.306956
# 2021-04-01                 0.306193    0.302512  ...    0.307307    0.306348
# 2021-05-01                 0.306522    0.308531  ...    0.306373    0.306485
# 2021-06-01                 0.310465    0.300457  ...    0.298574    0.309389
# 2021-07-01                 0.303086    0.312298  ...    0.303240    0.318517
# 2021-08-01                 0.305457    0.305679  ...    0.310781    0.314441
# 2021-09-01                 1.000000    0.312767  ...    0.323105    0.300295
# 2021-10-01                      NaN    1.000000  ...    0.317828    0.315636
# 2021-11-01                      NaN         NaN  ...    0.326379    0.298798
# 2021-12-01                      NaN         NaN  ...    0.338485    0.341476
# 2022-01-01                      NaN         NaN  ...    0.318318    0.287538
# 2022-02-01                      NaN         NaN  ...    0.387755    0.321729
# 2022-03-01                      NaN         NaN  ...    0.326333    0.316640
# 2022-04-01                      NaN         NaN  ...    0.339950    0.327543
# 2022-05-01                      NaN         NaN  ...    0.387597    0.317829
# 2022-06-01                      NaN         NaN  ...    0.414013    0.305732
# 2022-07-01                      NaN         NaN  ...    0.377358    0.349057
# 2022-08-01                      NaN         NaN  ...    0.426471    0.411765
# 2022-09-01                      NaN         NaN  ...    0.404255    0.404255
# 2022-10-01                      NaN         NaN  ...    0.310345    0.275862
# 2022-11-01                      NaN         NaN  ...    0.555556    0.444444
# 2022-12-01                      NaN         NaN  ...    0.285714    0.428571
# 2023-01-01                      NaN         NaN  ...    0.000000    0.000000
# 2023-02-01                      NaN         NaN  ...    0.000000    0.000000
# 2023-03-01                      NaN         NaN  ...    1.000000    1.000000
#
# month                    2023-05-01  2023-06-01  2023-07-01  2023-08-01  \
# first_transaction_month
# 2021-01-01                 0.299659    0.300473    0.300155    0.300942
# 2021-02-01                 0.300000    0.300665    0.299849    0.301505
# 2021-03-01                 0.301395    0.300081    0.305264    0.305138
# 2021-04-01                 0.308370    0.301216    0.311533    0.303860
# 2021-05-01                 0.305145    0.304959    0.310131    0.308196
# 2021-06-01                 0.304600    0.312026    0.309228    0.302663
# 2021-07-01                 0.304468    0.299632    0.304622    0.303624
# 2021-08-01                 0.314996    0.318101    0.313886    0.310115
# 2021-09-01                 0.303905    0.318018    0.308664    0.315720
# 2021-10-01                 0.303458    0.320019    0.320263    0.321481
# 2021-11-01                 0.330269    0.310467    0.322136    0.308699
# 2021-12-01                 0.314556    0.309571    0.332502    0.306082
# 2022-01-01                 0.319820    0.318318    0.319069    0.316066
# 2022-02-01                 0.339736    0.321729    0.338535    0.333733
# 2022-03-01                 0.327948    0.315024    0.342488    0.352181
# 2022-04-01                 0.364764    0.327543    0.354839    0.330025
# 2022-05-01                 0.379845    0.321705    0.337209    0.344961
# 2022-06-01                 0.382166    0.356688    0.401274    0.394904
# 2022-07-01                 0.433962    0.490566    0.443396    0.367925
# 2022-08-01                 0.294118    0.514706    0.455882    0.367647
# 2022-09-01                 0.468085    0.468085    0.425532    0.382979
# 2022-10-01                 0.517241    0.448276    0.379310    0.413793
# 2022-11-01                 0.611111    0.444444    0.500000    0.500000
# 2022-12-01                 0.571429    0.285714    0.571429    0.571429
# 2023-01-01                 1.000000    0.000000    0.000000    1.000000
# 2023-02-01                 1.000000    0.000000    0.000000    1.000000
# 2023-03-01                 1.000000    0.500000    1.000000    0.500000
#
# month                    2023-09-01  2023-10-01  2023-11-01  2023-12-01
# first_transaction_month
# 2021-01-01                 0.300765    0.298713    0.298394    0.300385
# 2021-02-01                 0.300928    0.301881    0.301505    0.300251
# 2021-03-01                 0.300171    0.303464    0.300351    0.304058
# 2021-04-01                 0.305234    0.304637    0.301086    0.301268
# 2021-05-01                 0.301239    0.306559    0.302578    0.305108
# 2021-06-01                 0.301803    0.308690    0.304170    0.305354
# 2021-07-01                 0.310533    0.314371    0.311300    0.309995
# 2021-08-01                 0.315217    0.311446    0.308341    0.314330
# 2021-09-01                 0.323597    0.298326    0.312110    0.317197
# 2021-10-01                 0.309791    0.316366    0.304433    0.309303
# 2021-11-01                 0.317539    0.321075    0.323904    0.322843
# 2021-12-01                 0.317547    0.321037    0.326022    0.328514
# 2022-01-01                 0.335586    0.330330    0.326577    0.320571
# 2022-02-01                 0.345738    0.325330    0.342137    0.325330
# 2022-03-01                 0.340872    0.348950    0.342488    0.332795
# 2022-04-01                 0.317618    0.325062    0.374690    0.322581
# 2022-05-01                 0.302326    0.372093    0.383721    0.356589
# 2022-06-01                 0.401274    0.331210    0.343949    0.343949
# 2022-07-01                 0.339623    0.349057    0.349057    0.292453
# 2022-08-01                 0.470588    0.397059    0.455882    0.485294
# 2022-09-01                 0.382979    0.468085    0.489362    0.340426
# 2022-10-01                 0.586207    0.344828    0.586207    0.310345
# 2022-11-01                 0.388889    0.555556    0.500000    0.333333
# 2022-12-01                 0.571429    1.000000    0.428571    0.571429
# 2023-01-01                 0.000000    0.000000    1.000000    0.000000
# 2023-02-01                 1.000000    1.000000    0.000000    1.000000
# 2023-03-01                 1.000000    0.500000    0.000000    0.000000
#
# [27 rows x 36 columns]

# %%
style_py = (retention_py
            .style
            .set_caption('User retention by cohort')
            .background_gradient(cmap='viridis')
            .highlight_null('white')
            .format("{:.2%}", na_rep=""))
style_py

# делаю более приятное оформление
# Out:
# <style  type="text/css" >
# #T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col0,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col1,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col2,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col3,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col4,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col5,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col11,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col13,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col16,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col17,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col2,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col3,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col4,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col5,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col13,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col17,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col5,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col17,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col11,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col14,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row8_col13,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row10_col18,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row16_col17,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row17_col19,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row19_col28,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row21_col22,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row23_col24,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row23_col25,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col26,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col27,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col29,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col30,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col32,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col33,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row24_col35,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row25_col26,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row25_col27,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row25_col29,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row25_col30,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row25_col34,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row26_col34,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row26_col35{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col14,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col28,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col11,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col14,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col16,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col18,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col28,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col4,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col16,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col28,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col14,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col17,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col5,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col7,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col11,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row8_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row10_col31{
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col18,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row1_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col3,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col10,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col11,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col13,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row2_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col4,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col5,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col13,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row3_col31,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col6,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col16,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row4_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col9,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col12,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row6_col21,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col8,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col16,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col20,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row8_col18,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row11_col31{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col19,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row11_col24,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row14_col15,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row14_col24,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row22_col24{
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }#T_b9039632_c10a_11ee_bdbb_96000040dfb6row0_col22,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row5_col19,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row7_col19,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row15_col23,#T_b9039632_c10a_11ee_bdbb_96000040dfb6row15_col24{
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }#T_b9039632_c10a_11ee_bdbb_96000040dfb6ro

# %%
excel_file_path = 'retention_py.xlsx'
retention_py.to_excel(excel_file_path, index=False)

print(f'Таблица сохранена в файл {excel_file_path}')
# Out:
# Таблица сохранена в файл retention_py.xlsx

# %% [markdown]
# В конце концов сейвлю расчет.

# %%
monthly_activity[monthly_activity['first_transaction_month'] == '2023-03-01']
# Out:
#          account_id first_transaction_month      month  amount  active
# 1002140       79899              2023-03-01 2023-03-01  1694.0       1
# 1002141       79899              2023-03-01 2023-04-01   865.0       1
# 1002142       79899              2023-03-01 2023-05-01   642.0       1
# 1002143       79899              2023-03-01 2023-06-01  1053.0       1
# 1002144       79899              2023-03-01 2023-07-01  1404.0       1
# 1002145       79899              2023-03-01 2023-08-01     NaN       0
# 1002146       79899              2023-03-01 2023-09-01   536.0       1
# 1002147       79899              2023-03-01 2023-10-01     NaN       0
# 1002148       79899              2023-03-01 2023-11-01     NaN       0
# 1002149       79899              2023-03-01 2023-12-01     NaN       0
# 8775829      696104              2023-03-01 2023-03-01   653.0       1
# 8775830      696104              2023-03-01 2023-04-01  1601.0       1
# 8775831      696104              2023-03-01 2023-05-01   717.0       1
# 8775832      696104              2023-03-01 2023-06-01     NaN       0
# 8775833      696104              2023-03-01 2023-07-01   642.0       1
# 8775834      696104              2023-03-01 2023-08-01   621.0       1
# 8775835      696104              2023-03-01 2023-09-01  1278.0       1
# 8775836      696104              2023-03-01 2023-10-01   799.0       1
# 8775837      696104              2023-03-01 2023-11-01     NaN       0
# 8775838      696104              2023-03-01 2023-12-01     NaN       0

# %% [markdown]
# Ретеншн за последние месяцы первой активности пользователей показались мне странными, но когда я вывел дебаг, все встало на свои места - пользователей с первой активностью в последние месяцы временного промежутка очень мало, тем самым и скачет процент.

# %% [markdown]
# ---
# ### 3) SQL

# %%
con = sqlite3.connect('database.db')
active_users.to_sql('cleared_data', con, index=False, if_exists='replace')

# %%
sql = 'select * from cleared_data limit 50'
result = pd.read_sql(sql, con)
result.head()
# Out:
#    account_id purchase_date  amount  status project_name  \
# 0      474724    2022-12-31     584  active           fm
# 1      474724    2022-04-30     529  active           fm
# 2      474724    2021-03-31     722  active           fm
# 3      474724    2023-04-30     820  active           fm
# 4      474724    2021-05-31     775  active           fm
#
#   first_transaction_month
# 0     2022-12-01 00:00:00
# 1     2022-04-01 00:00:00
# 2     2021-03-01 00:00:00
# 3     2023-04-01 00:00:00
# 4     2021-05-01 00:00:00

# %% [markdown]
# Загружаю подготовленный дф в базу и отображаю, чтобы убедиться, что все пошло по плану.

# %%
min = '''select date(min(purchase_date), 'start of month') from cleared_data '''

min_data = pd.read_sql(min, con)
min_data
# Out:
#   date(min(purchase_date), 'start of month')
# 0                                 2021-01-01

# %%
max = '''select date(max(purchase_date), 'start of month') from cleared_data '''

max_data = pd.read_sql(max, con)
max_data
# Out:
#   date(max(purchase_date), 'start of month')
# 0                                 2023-12-01

# %% [markdown]
# Расчитал промежутки (мин макс)

# %%
months = f'''
    WITH RECURSIVE dates(date) AS (
        VALUES (({min}))
        UNION ALL
        SELECT DATE(date, '+1 month')
        FROM dates
        WHERE date < ({max})
    )
    SELECT date FROM dates
    LIMIT 5
'''

months_data = pd.read_sql(months, con)

months_data.head()
# Out:
#          date
# 0  2021-01-01
# 1  2021-02-01
# 2  2021-03-01
# 3  2021-04-01
# 4  2021-05-01

# %% [markdown]
# Написал и проверил рекурсивный запрос для генерации последовательности даты в нужном промежутке.
#
# Ниже основной код:

# %%
sql = f'''

-- Временная таблица id_ftm, с первой транзакцией для каждого айдишника
WITH id_ftm AS (
        SELECT 
               -- Формирую выборку account_id и первой даты транзакции, округленной до начала месяца
               account_id, 
               DATE(MIN(purchase_date), 'start of month') AS first_transaction_month
        FROM 
               cleared_data
        GROUP BY 
               account_id
    ),

    -- Временная таблица dates с рекурсивным запросом календаря
    dates AS (
        WITH RECURSIVE dates(date) AS (
            VALUES (({min}))
            UNION ALL
            SELECT DATE(date, '+1 month')
            FROM dates
            WHERE date < ({max})
        )
        SELECT date FROM dates
    ),
    
    -- Временная таблица monthly_data_dynamics с объединением id_ftm и dates
    monthly_data_dynamics AS (
        SELECT 
               ftm.account_id, 
               ftm.first_transaction_month, 
               dts.date AS month 
        FROM 
               id_ftm ftm
        JOIN dates dts ON dts.date >= ftm.first_transaction_month
    ),

    -- Временная таблица trans_month с суммами транзакций для каждого месяца и аккаунта
    trans_month AS (
        SELECT 
            account_id, 
            DATE((purchase_date), 'start of month') AS month,
            SUM(amount) AS amount_sum
        FROM cleared_data
        GROUP BY account_id, 
                 DATE((purchase_date), 'start of month')
    ),

    -- Временная таблица monthly_activity объединяющая данные monthly_data_dynamics и trans_month
    monthly_activity AS (
        SELECT 
               mdd.*, 
               tm.amount_sum,
               -- Написал флаг active 0 или 1
               CASE WHEN tm.amount_sum > 0 THEN 1 ELSE 0 END AS active
        FROM 
               monthly_data_dynamics mdd
        LEFT JOIN trans_month tm ON mdd.account_id = tm.account_id AND mdd.month = tm.month
    )

-- Окончательный запрос, выводящий ретеншн в процентах, округленный до сотых
SELECT 
       first_transaction_month, 
       month, 
       ROUND(AVG(active) * 100, 2) AS retention
FROM 
       monthly_activity 
GROUP BY 
       first_transaction_month, 
       month

'''


retention_sql = pd.read_sql(sql, con)
retention_sql
# Out:
#     first_transaction_month       month  retention
# 0                2021-01-01  2021-01-01     100.00
# 1                2021-01-01  2021-02-01      30.22
# 2                2021-01-01  2021-03-01      30.04
# 3                2021-01-01  2021-04-01      29.98
# 4                2021-01-01  2021-05-01      29.93
# ..                      ...         ...        ...
# 616              2023-03-01  2023-08-01      50.00
# 617              2023-03-01  2023-09-01     100.00
# 618              2023-03-01  2023-10-01      50.00
# 619              2023-03-01  2023-11-01       0.00
# 620              2023-03-01  2023-12-01       0.00
#
# [621 rows x 3 columns]

# %% [markdown]
# Далее пишу пивотник для красивого отображения результата.

# %%
retention_sql = retention_sql.pivot_table(index='first_transaction_month', columns='month', values='retention')
retention_sql
# Out:
# month                    2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# first_transaction_month
# 2021-01-01                    100.0       30.22       30.04       29.98
# 2021-02-01                      NaN      100.00       30.01       30.09
# 2021-03-01                      NaN         NaN      100.00       30.50
# 2021-04-01                      NaN         NaN         NaN      100.00
# 2021-05-01                      NaN         NaN         NaN         NaN
# 2021-06-01                      NaN         NaN         NaN         NaN
# 2021-07-01                      NaN         NaN         NaN         NaN
# 2021-08-01                      NaN         NaN         NaN         NaN
# 2021-09-01                      NaN         NaN         NaN         NaN
# 2021-10-01                      NaN         NaN         NaN         NaN
# 2021-11-01                      NaN         NaN         NaN         NaN
# 2021-12-01                      NaN         NaN         NaN         NaN
# 2022-01-01                      NaN         NaN         NaN         NaN
# 2022-02-01                      NaN         NaN         NaN         NaN
# 2022-03-01                      NaN         NaN         NaN         NaN
# 2022-04-01                      NaN         NaN         NaN         NaN
# 2022-05-01                      NaN         NaN         NaN         NaN
# 2022-06-01                      NaN         NaN         NaN         NaN
# 2022-07-01                      NaN         NaN         NaN         NaN
# 2022-08-01                      NaN         NaN         NaN         NaN
# 2022-09-01                      NaN         NaN         NaN         NaN
# 2022-10-01                      NaN         NaN         NaN         NaN
# 2022-11-01                      NaN         NaN         NaN         NaN
# 2022-12-01                      NaN         NaN         NaN         NaN
# 2023-01-01                      NaN         NaN         NaN         NaN
# 2023-02-01                      NaN         NaN         NaN         NaN
# 2023-03-01                      NaN         NaN         NaN         NaN
#
# month                    2021-05-01  2021-06-01  2021-07-01  2021-08-01  \
# first_transaction_month
# 2021-01-01                    29.93       30.11       29.97       30.01
# 2021-02-01                    30.04       30.25       30.43       30.15
# 2021-03-01                    30.63       30.19       30.58       30.12
# 2021-04-01                    30.47       30.60       30.54       30.28
# 2021-05-01                   100.00       30.77       30.37       30.61
# 2021-06-01                      NaN      100.00       30.15       30.02
# 2021-07-01                      NaN         NaN      100.00       31.37
# 2021-08-01                      NaN         NaN         NaN      100.00
# 2021-09-01                      NaN         NaN         NaN         NaN
# 2021-10-01                      NaN         NaN         NaN         NaN
# 2021-11-01                      NaN         NaN         NaN         NaN
# 2021-12-01                      NaN         NaN         NaN         NaN
# 2022-01-01                      NaN         NaN         NaN         NaN
# 2022-02-01                      NaN         NaN         NaN         NaN
# 2022-03-01                      NaN         NaN         NaN         NaN
# 2022-04-01                      NaN         NaN         NaN         NaN
# 2022-05-01                      NaN         NaN         NaN         NaN
# 2022-06-01                      NaN         NaN         NaN         NaN
# 2022-07-01                      NaN         NaN         NaN         NaN
# 2022-08-01                      NaN         NaN         NaN         NaN
# 2022-09-01                      NaN         NaN         NaN         NaN
# 2022-10-01                      NaN         NaN         NaN         NaN
# 2022-11-01                      NaN         NaN         NaN         NaN
# 2022-12-01                      NaN         NaN         NaN         NaN
# 2023-01-01                      NaN         NaN         NaN         NaN
# 2023-02-01                      NaN         NaN         NaN         NaN
# 2023-03-01                      NaN         NaN         NaN         NaN
#
# month                    2021-09-01  2021-10-01  ...  2023-03-01  2023-04-01  \
# first_transaction_month                          ...
# 2021-01-01                    30.06       29.77  ...       30.21       30.00
# 2021-02-01                    30.10       30.17  ...       30.24       30.05
# 2021-03-01                    30.68       30.12  ...       30.24       30.70
# 2021-04-01                    30.62       30.25  ...       30.73       30.63
# 2021-05-01                    30.65       30.85  ...       30.64       30.65
# 2021-06-01                    31.05       30.05  ...       29.86       30.94
# 2021-07-01                    30.31       31.23  ...       30.32       31.85
# 2021-08-01                    30.55       30.57  ...       31.08       31.44
# 2021-09-01                   100.00       31.28  ...       32.31       30.03
# 2021-10-01                      NaN      100.00  ...       31.78       31.56
# 2021-11-01                      NaN         NaN  ...       32.64       29.88
# 2021-12-01                      NaN         NaN  ...       33.85       34.15
# 2022-01-01                      NaN         NaN  ...       31.83       28.75
# 2022-02-01                      NaN         NaN  ...       38.78       32.17
# 2022-03-01                      NaN         NaN  ...       32.63       31.66
# 2022-04-01                      NaN         NaN  ...       34.00       32.75
# 2022-05-01                      NaN         NaN  ...       38.76       31.78
# 2022-06-01                      NaN         NaN  ...       41.40       30.57
# 2022-07-01                      NaN         NaN  ...       37.74       34.91
# 2022-08-01                      NaN         NaN  ...       42.65       41.18
# 2022-09-01                      NaN         NaN  ...       40.43       40.43
# 2022-10-01                      NaN         NaN  ...       31.03       27.59
# 2022-11-01                      NaN         NaN  ...       55.56       44.44
# 2022-12-01                      NaN         NaN  ...       28.57       42.86
# 2023-01-01                      NaN         NaN  ...        0.00        0.00
# 2023-02-01                      NaN         NaN  ...        0.00        0.00
# 2023-03-01                      NaN         NaN  ...      100.00      100.00
#
# month                    2023-05-01  2023-06-01  2023-07-01  2023-08-01  \
# first_transaction_month
# 2021-01-01                    29.97       30.05       30.02       30.09
# 2021-02-01                    30.00       30.07       29.98       30.15
# 2021-03-01                    30.14       30.01       30.53       30.51
# 2021-04-01                    30.84       30.12       31.15       30.39
# 2021-05-01                    30.51       30.50       31.01       30.82
# 2021-06-01                    30.46       31.20       30.92       30.27
# 2021-07-01                    30.45       29.96       30.46       30.36
# 2021-08-01                    31.50       31.81       31.39       31.01
# 2021-09-01                    30.39       31.80       30.87       31.57
# 2021-10-01                    30.35       32.00       32.03       32.15
# 2021-11-01                    33.03       31.05       32.21       30.87
# 2021-12-01                    31.46       30.96       33.25       30.61
# 2022-01-01                    31.98       31.83       31.91       31.61
# 2022-02-01                    33.97       32.17       33.85       33.37
# 2022-03-01                    32.79       31.50       34.25       35.22
# 2022-04-01                    36.48       32.75       35.48       33.00
# 2022-05-01                    37.98       32.17       33.72       34.50
# 2022-06-01                    38.22       35.67       40.13       39.49
# 2022-07-01                    43.40       49.06       44.34       36.79
# 2022-08-01                    29.41       51.47       45.59       36.76
# 2022-09-01                    46.81       46.81       42.55       38.30
# 2022-10-01                    51.72       44.83       37.93       41.38
# 2022-11-01                    61.11       44.44       50.00       50.00
# 2022-12-01                    57.14       28.57       57.14       57.14
# 2023-01-01                   100.00        0.00        0.00      100.00
# 2023-02-01                   100.00        0.00        0.00      100.00
# 2023-03-01                   100.00       50.00      100.00       50.00
#
# month                    2023-09-01  2023-10-01  2023-11-01  2023-12-01
# first_transaction_month
# 2021-01-01                    30.08       29.87       29.84       30.04
# 2021-02-01                    30.09       30.19       30.15       30.03
# 2021-03-01                    30.02       30.35       30.04       30.41
# 2021-04-01                    30.52       30.46       30.11       30.13
# 2021-05-01                    30.12       30.66       30.26       30.51
# 2021-06-01                    30.18       30.87       30.42       30.54
# 2021-07-01                    31.05       31.44       31.13       31.00
# 2021-08-01                    31.52       31.14       30.83       31.43
# 2021-09-01                    32.36       29.83       31.21       31.72
# 2021-10-01                    30.98       31.64       30.44       30.93
# 2021-11-01                    31.75       32.11       32.39       32.28
# 2021-12-01                    31.75       32.10       32.60       32.85
# 2022-01-01                    33.56       33.03       32.66       32.06
# 2022-02-01                    34.57       32.53       34.21       32.53
# 2022-03-01                    34.09       34.89       34.25       33.28
# 2022-04-01                    31.76       32.51       37.47       32.26
# 2022-05-01                    30.23       37.21       38.37       35.66
# 2022-06-01                    40.13       33.12       34.39       34.39
# 2022-07-01                    33.96       34.91       34.91       29.25
# 2022-08-01                    47.06       39.71       45.59       48.53
# 2022-09-01                    38.30       46.81       48.94       34.04
# 2022-10-01                    58.62       34.48       58.62       31.03
# 2022-11-01                    38.89       55.56       50.00       33.33
# 2022-12-01                    57.14      100.00       42.86       57.14
# 2023-01-01                     0.00        0.00      100.00        0.00
# 2023-02-01                   100.00      100.00        0.00      100.00
# 2023-03-01                   100.00       50.00        0.00        0.00
#
# [27 rows x 36 columns]

# %%
style_sql = (retention_sql
            .style
            .set_caption('User retention by cohort')
            .background_gradient(cmap='viridis')
            .highlight_null('white')
            .format("{:}%", na_rep=""))
style_sql
# Out:
# <style  type="text/css" >
# #T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col0,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col1,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col2,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col3,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col4,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col5,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col11,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col13,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col16,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col17,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col2,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col3,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col4,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col5,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col13,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col17,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col5,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col17,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col11,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col14,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row8_col13,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row10_col18,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row16_col17,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row17_col19,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row19_col28,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row21_col22,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row23_col24,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row23_col25,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col26,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col27,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col29,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col30,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col32,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col33,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row24_col35,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row25_col26,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row25_col27,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row25_col29,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row25_col30,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row25_col34,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row26_col34,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row26_col35{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col14,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col28,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col14,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col16,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col18,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col28,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col4,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col16,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col28,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col14,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col17,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col5,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col7,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col11,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row8_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row10_col31{
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col18,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col11,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row1_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col3,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col10,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col11,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col13,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row2_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col4,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col5,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col13,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row3_col31,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col6,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col16,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row4_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col9,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col12,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row6_col21,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col8,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col16,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col20,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row8_col18,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row11_col31{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col19,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row11_col24,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row14_col15,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row14_col24,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row22_col24{
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row0_col22,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row5_col19,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row7_col19,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row15_col23,#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6row15_col24{
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }#T_ae91e02c_c10b_11ee_bdbb_96000040dfb6ro

# %%
excel_file_path = 'retention_sql.xlsx'
retention_sql.to_excel(excel_file_path, index=False)

print(f'Таблица сохранена в файл {excel_file_path}')
# Out:
# Таблица сохранена в файл retention_sql.xlsx

# %% [markdown]
# ---
# ### 4) Вывод по Ретеншну по Когортам:
#
# 1. Ретеншн пользователей в целом демонстрирует постепенное снижение с течением времени для большинства когорт. Это типичный паттерн для многих отраслей.
#
# 2. Первые когорты (например, январь 2021 года) имеют более высокие показатели ретеншна в первые месяцы по сравнению с поздними когортами. Некоторые когорты имеют отклонения в показателях ретеншна, в то время как у других наблюдается более стабильное снижение. Несколько когорт поддерживают стабильный показатель ретеншна даже после нескольких месяцев => устойчивая база пользователей.
#
# 3. Есть и аномалии, например, резкие снижения или повышения показателей ретеншна, они могут быть обусловлены внешними факторами, изменениями в продукте/услуге или действиями отдела маркетинга.
#
# 4. Для улучшения общего ретеншна лучше применить более глубокий анализ поведения пользователей, их предпочтений и возможных проблем. Например, индивидуализированные маркетинговые стратегии вовлечения, основанные на наблюдаемых паттернах в когортах с высоким ретеншном.

# %% [markdown]
# ### 5) Мнение по значимости и расчету метрики ретеншн для бизнеса:
#
# Зачем важно считать ретеншн?
#
# 1. Ретеншн - это ключевой показатель, отражающий то, насколько успешно бизнес удерживает клиентов с течением времени. Высокий ретеншн свидетельствует о долгосрочной лояльности клиентов, что может быть критически важным для устойчивого развития.
#
# 2. Расходы на привлечение новых клиентов могут быть значительными, в то время как удержание существующих может сэкономить средства.
#
# 3. Ретеншн также служит индикатором удовлетворенности клиентов. Высокие показатели ретеншна свидетельствуют о качественных продуктах или услугах, что может быть важным конкурентным преимуществом.
#
# 4. Стабильный ретеншн облегчает прогнозирование будущих поступлений и тем самым позволяет бизнесу более точно планировать свои стратегии и расходы.
# ---
# Нюансы при расчете ретеншна:
#
# 1. Необходимо четко определить временной интервал для расчета ретеншна.
#
# 2. Каждый бизнес уникален, и метрика ретеншна может иметь разную значимость в зависимости от отрасли и типа продукта/услуги. Важно учитывать специфику бизнеса при интерпретации показателей.
#
# 3. При расчёте важно учитывать другие метрики и факторы, например, маркетинговые инициативы, обновления продукта и конкурентная обстановка.
#
# 4. В некоторых отраслях ретеншн может подвергаться влиянию сезонных колебаний, это также нужно учитывать.
#
#
# ---
# Заключение:
#
# Ретеншн представляет собой важную метрику для бизнеса, и игнорирование ее может привести к потере ценных клиентов и упущенным возможностям для экономии ресурсов. Этот показатель не только отражает текущую устойчивость, но и отражает возможности потенциального роста. Необходимо учитывать контекст и особенности своего бизнеса при интерпретации результатов и принятии решений при анализе ретеншна.
